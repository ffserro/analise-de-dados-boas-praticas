# %%
# %sql
select * from dados_fa.pessoal.org_xml 
where pubName = "DO2"
order by id desc
limit 5;

# %%
# %sql
select count(*) from dados_fa.pessoal.org_xml;

# %%
# %sql
select * from dados_fa.pessoal.org_xml
where error_parse is not null

# %%
# %sql
select distinct pubName, artType, count(*) as amount from dados_fa.pessoal.org_xml
group by pubName, artType
order by amount desc

# %%
# %sql
select * from dados_fa.pessoal.org_xml 
where pubName is null

# %%
# %sql
update dados_fa.pessoal.org_xml
set artType = 'PORTARIA'
where upper(artType) like 'PORTARIA%'

# %%
with open('/Volumes/dados_fa/pessoal/xml_files/S01042002/12002040127.xml', 'r') as file:
    print(file.read())

# %%
# %sql
delete from dados_fa.pessoal.org_xml
where texto is null

# %%
# %sql 
select arquivo_origem, texto, error_parse
from dados_fa.pessoal.org_xml
where texto is null

# %%
with open('/Volumes/dados_fa/pessoal/xml_files/S01122017/10420659.xml', 'r') as file:
    print(file.read())
